# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav-rathor/TinyTorch/blob/main/TinyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/keshav-rathor/TinyTorch
# Out:
# Cloning into 'TinyTorch'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
